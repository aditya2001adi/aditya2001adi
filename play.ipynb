# %%
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
penguins = pd.read_csv("penguins.csv")
plt.plot(penguins.year, penguins.bill_depth_mm)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
